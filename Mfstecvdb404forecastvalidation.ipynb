# %%
#enter loop
#ask for query specifications (data range)
#either specify location or loop through all locations
#query sql with specified range, store to df
#reformat df same as hist data script
#update prevec too
#get embeddings
#create forecast using filter by location on historical data
#within each element: amplitude boost based on region
#smooth result
#print result and graphs
#ask if it should be stored to sql
#if yes, reformat to sql table format, then insert

# %%
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter
import pymilvus
import time as time
import math
import matplotlib.pyplot as plt
import statsmodels.api as sm
from pathlib import Path
from pymilvus import (
    connections,
    utility,
    FieldSchema, CollectionSchema, DataType,
    Collection,
)

from sqlalchemy import create_engine, MetaData, text
from sqlalchemy.engine import URL
import pypyodbc

plt.rcParams['figure.figsize'] = [12, 5] #plot size 10"w x 5"h

# set up embedding model
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

#initialize df for access outside of while loop
df = pd.DataFrame()



#while loop allows user to run multiple times
run_again = 'y'
while(run_again == 'y' or run_again == 'yes' or run_again == 'Y' or run_again == 'Yes'):

    ####################################
    # connect to milvus vdb
    connections.connect(
      alias="default",
      user='root',
      password='tecafs',
      host='localhost',
      port='19530'
    )

    ###################################
    # connect to SQL
    # declares the variables and defines them for the server connections, along with the table names that are going to be assigned
    SERVER_NAME = 'tcp:tecafs.database.windows.net,1433'
    DATABASE_NAME = 'TecafsSqlDatabase'
    TABLE_NAME = 'hist_data'
    
    # makes the connection to the database with the connection string; has the driver, server name, database name, id, and password
    connection_string = f"""
      DRIVER={{ODBC Driver 18 for SQL Server}};
      SERVER={SERVER_NAME};
      DATABASE={DATABASE_NAME};
      Uid={'tecafs2023'};
      Pwd={'Capstone50'};
    """
    
    connection_url = URL.create('mssql+pyodbc', query={'odbc_connect': connection_string})
    engine = create_engine(connection_url, module=pypyodbc)  
    
    ###################################

    # Get user input for the range of data
    start_date = input("Enter start date in 2023 in format (YYYY-MM-DD): ")
    end_date = input("Enter end date (inclusive) in 2023 in format (YYYY-MM-DD): ")
    #location = input("Enter location from options: COAST, EAST, FAR_WEST, NORTH, NORTH_C, SOUTHERN, SOUTH_C, WEST: ")

    locationslist = ['COAST', 'EAST', 'FAR_WEST', 'NORTH', 'NORTH_C', 'SOUTHERN', 'SOUTH_C', 'WEST']

    for i in range(8):
        location = locationslist[i]
    
        start_time = time.time()
    
        # Define the SQL query with placeholders for user input
        sql_query = """
        SELECT *
        FROM hist_data
        WHERE Time >= ? AND Time <= ?
        AND Location = ?
        """
        
        # Execute the query with user input as parameters
        df = pd.read_sql_query(sql_query, engine, params = (start_date, end_date, location))
    
        ##################################
        
        #fix df formatting
        #df = df.drop(columns=['dew point', 'wind', 'wind gust', 'pressure', 'precip.'])
        #df = df.rename(columns={"wind speed": "wind_speed"})
        df['year'] = df['time'].dt.year.astype(int)
        df['date'] = df['time'].dt.strftime('%m-%d')
        df['hour'] = df['time'].dt.strftime('%H:%M')
        
    
        df = df.sort_values(by=['location', 'time']) #sorts by datetime within each location
        df = df.reset_index(drop=True)
        
        #reorder columns to match vdb
        #df = df[['vector', 'location', 'time', 'year', 'date', 'hour', 'temperature', 'humidity', 'wind_speed', 'condition', 'power']]
            
        ###################################
    
        #define embedding function
        def get_embedding(prevec):
            text = prevec
            embedding = model.encode(text, show_progress_bar = False)
            return embedding
        
        # Create the prevec conglomeration by combining values from other columns and embed it into 'vector' column 
        df['vector'] = df.apply(lambda row: get_embedding(f"{row['year']}/{row['date']}/{row['hour']}/{row['hour']}/{row['hour']}/{row['temperature']}/{row['temperature']}/{row['humidity']}/{row['wind speed']}/{row['condition']}"), axis=1)
    
        ##################################
        
        collection = Collection("historical_data_21_22")  #get existing milvus collection
        collection.load()  #load collection
        
        def search(text, hour, date, year, location, top_k = 10):
            # AUTOINDEX does not require any search params, chosen to specify metric
            search_params = {
              "metric_type": "L2",
              
            }
            
            #do similarity search
            results = collection.search(
              data = [text],
              anns_field='vector',
              param=search_params,
              limit = top_k,  # Limit to top_k results per search
              expr='location=="{0}"'.format(location),
              output_fields=['index', 'location', 'year', 'date', 'hour', 'temperature', 'humidity', 'wind_speed', 'condition', 'power']
            )
            avg_power = 0
            
            #sum the top_k power values
            for hit in  results[0]:
                #print (hit.entity.get(['location', 'year', 'date', 'hour', 'temperature', 'humidity', 'wind_speed', 'condition', 'power']))
                avg_power += (hit.entity.get('power')*(1.015**(year-hit.entity.get('year')))) #normalize to current year equivalent - 1.5% increase per year
                
            
            #calculate average power, adjust to tune for best results
            month = int(date.split('-')[0])
            hr = int(hour.split(':')[0])
            
            yearly_amp = (-1000*math.sin((math.pi/6)*(month-1)+1))+(300*math.sin((math.pi/3)*(month-1)+1))+1700
            
            #avg_power= (-(yearly_amp)*math.sin((math.pi/12)*hr))+(avg_power/top_k)
            #avg_power= (-500*math.sin((math.pi/12)*hr))+(avg_power/top_k)
            avg_power= (avg_power/top_k)
            return avg_power

            #normalization percentage variable throughout year on bell curve - 0-5%
            #amplitude boost variable throughout year on bell curve (start above 0 boost, increase to max boost in august), also as a function of current value
    
        ##################################
    
        df['forecast_power'] = df.apply(lambda row: search(row['vector'], row['hour'], row['date'], row['year'], row['location']), axis=1)  
        
        ##################################
        
        #Calculate percent error for each row
        df['percent_error'] = ((abs(df['forecast_power'] - df['power'])) / df['power']) * 100
        
        #Calculate overall percent error
        mean_percent_error = df['percent_error'].mean()
    
    
        
        #apply savitsky-golay filter for smoothing
        df['forecast_savgol'] = df[['forecast_power']].apply(lambda x: savgol_filter(x,18,3))
        
        #Calculate savgol percent error for each row
        df['savgol_percent_error'] = ((abs(df['forecast_savgol'] - df['power'])) / df['power']) * 100
        
        #Calculate overall savgol percent error
        savgol_mean_percent_error = df['savgol_percent_error'].mean()
    
        ##################################
        
        end_time = time.time()
        elapsed_time = end_time - start_time
        
        # Write the modified DataFrame back to a new CSV file
        data_folder = Path("/mnt/c/Users/wcans/milvus_compose/ERCOT_Hourly_Load_2022/")
        output_csv_file_path = data_folder / '2023forecast_out.csv'  # Replace with the desired output path
        #not enabled at the moment
        #df.to_csv(output_csv_file_path, index=False)
    
        #print data
        #create and print plots
        df.plot(x="date", y=["forecast_power", "power", "forecast_savgol"], kind="line")
        # Display the plot
        plt.title('Forecast Power vs Actual Power Over Time')
        plt.xlabel('Date')
        plt.ylabel('Power (megawatt-hours)')
        plt.legend(['Forecast Power', 'Power', 'SavGol Forecast'])
        plt.savefig('power_figure.png')
        plt.show(block=True)
        
        
        df.plot(x='date', y=['percent_error', 'savgol_percent_error'], kind='line')
        # Display the plot
        plt.title('Percent Error')
        plt.xlabel('Date')
        plt.ylabel('Percentage')
        plt.legend(['Forecast Error', 'SavGol Error'])
        plt.savefig('error_figure.png')
        plt.show(block=True)
        
        print('Mean Average Percent Error - base forecast: ', mean_percent_error)
        print('Mean Average Percent Error - savgol forecast: ', savgol_mean_percent_error)
        print(f"Forecast Generation Time: {elapsed_time} seconds")
        print('-------------------------------')
    
        '''
        #check for missing hours in the forecast
        expected_diff = pd.Timedelta(hours=1)
        rollover_diff = pd.Timedelta(hours=23)
        
        #convert time to datetime
        df['time'] = pd.to_datetime(df['time'], format='%H:%M')
        
        # Calculate the actual difference between each consecutive datetime
        time_diff = df['time'].diff()
        
        # Find the rows where the difference is not as expected
        missing_hours = df[(time_diff != expected_diff) & (time_diff != rollover_diff)]
        missing_hours['time'] = missing_hours['time'].dt.strftime('%H:%M')
        
        # Print a notification if there are missing hours
        if not missing_hours.empty:
          print("Notification: Missing hour(s) detected between the following timestamps:")
          print(missing_hours[['date', 'time']])
        else:
          print("No missing hours detected.")
        
        #convert time back to strings
        df['time'] = df['time'].dt.strftime('%H:%M')
        '''
        df = df.drop(columns=['vector']) #'time_diff', 'missing_hours'
        
        print(df)
        
        #Format forecast for insertion
        df = df.drop(columns=['power', 'percent_error', 'forecast_power', 'savgol_percent_error'])
        
        new_column_name = 'forecast power'
        df.rename(columns={'forecast_savgol': new_column_name}, inplace=True)
        
        #Add to SQL
        df.to_sql('Milvus_forecast', con=engine, if_exists='append', index=False)
        
    # User Interface
    run_again = input('Would you like to run again? (y/n)')
# Out:
# Enter start date in 2023 in format (YYYY-MM-DD):  2023-04-01
# Enter end date (inclusive) in 2023 in format (YYYY-MM-DD):  2023-04-14
# Mean Average Percent Error - base forecast:  12.574467037611964
# Mean Average Percent Error - savgol forecast:  12.174040371967905
# Forecast Generation Time: 126.36864709854126 seconds
# -------------------------------
#     location                time  temperature  dew point  humidity  wind  \
# 0      COAST 2023-04-01 00:00:00         75.0       72.0      90.0     S
# 1      COAST 2023-04-01 01:00:00         74.0       70.0      87.0   SSE
# 2      COAST 2023-04-01 02:00:00         75.0       71.0      87.0  CALM
# 3      COAST 2023-04-01 03:00:00         74.0       71.0      91.0    SW
# 4      COAST 2023-04-01 04:00:00         73.0       71.0      93.0     W
# ..       ...                 ...          ...        ...       ...   ...
# 308    COAST 2023-04-13 20:00:00         71.0       57.0      61.0   SSE
# 309    COAST 2023-04-13 21:00:00         69.0       59.0      70.0     S
# 310    COAST 2023-04-13 22:00:00         68.0       58.0      70.0     S
# 311    COAST 2023-04-13 23:00:00         66.0       59.0      78.0   SSE
# 312    COAST 2023-04-14 00:00:00         64.0       58.0      80.0   SSE
#
#      wind speed  wind gust  pressure  precip.      condition     power  year  \
# 0           5.0        0.0     29.95      0.0         Cloudy  12420.01  2023
# 1           8.0        0.0     29.95      0.0  Mostly Cloudy  11972.31  2023
# 2           0.0        0.0     29.99      0.0         Cloudy  11440.83  2023
# 3           5.0        0.0     29.97      0.0  Mostly Cloudy  11015.03  2023
# 4           6.0        0.0     29.97      0.0  Partly Cloudy  10726.01  2023
# ..          ...        ...       ...      ...            ...       ...   ...
# 308        12.0        0.0     29.74      0.0  Partly Cloudy  12982.22  2023
# 309         9.0        0.0     29.75      0.0           Fair  12936.51  2023
# 310         7.0        0.0     29.77      0.0           Fair  12601.23  2023
# 311         6.0        0.0     29.78      0.0           Fair  11929.95  2023
# 312         5.0        0.0     29.77      0.0           Fair  11136.59  2023
#
#       date   hour  forecast_power  percent_error  forecast_savgol  \
# 0    04-01  00:00    12001.769045       3.367477     12615.465005
# 1    04-01  01:00    12517.892485       4.557036     12238.256259
# 2    04-01  02:00    12435.049200       8.690097     11983.279920
# 3    04-01  03:00    11903.678430       8.067599     11838.859563
# 4    04-01  04:00    12167.124725      13.435702     11793.318763
# ..     ...    ...             ...            ...              ...
# 308  04-13  20:00    14825.352885      14.197363     14481.667946
# 309  04-13  21:00    13425.165460       3.777336     14344.681497
# 310  04-13  22:00    12968.380950       2.913612     14097.516840
# 311  04-13  23:00    14828.508520      24.296485     13727.436880
# 312  04-14  00:00    13451.217465      20.783987     13221.704525
#
#      savgol_percent_error
# 0                1.573711
# 1                2.221345
# 2                4.741351
# 3                7.479140
# 4                9.950660
# ..                    ...
# 308             11.550012
# 309             10.885250
# 310             11.874133
# 311             15.067011
# 312             18.723097
#
# [313 rows x 19 columns]
# Mean Average Percent Error - base forecast:  12.2737514410086
# Mean Average Percent Error - savgol forecast:  11.83559435399781
# Forecast Generation Time: 119.40925192832947 seconds
# -------------------------------
#     location                time  temperature  dew point  humidity wind  \
# 0       EAST 2023-04-01 00:00:00         66.0       40.0      38.0   SW
# 1       EAST 2023-04-01 01:00:00         73.0       65.0      76.0    S
# 2       EAST 2023-04-01 02:00:00         61.0       52.0      72.0   SW
# 3       EAST 2023-04-01 04:00:00         58.0       47.0      67.0  SSW
# 4       EAST 2023-04-01 05:00:00         59.0       40.0      49.0  SSW
# ..       ...                 ...          ...        ...       ...  ...
# 292     EAST 2023-04-13 20:00:00         68.0       53.0      59.0  SSE
# 293     EAST 2023-04-13 21:00:00         64.0       53.0      67.0   SE
# 294     EAST 2023-04-13 22:00:00         63.0       53.0      70.0  SSE
# 295     EAST 2023-04-13 23:00:00         62.0       53.0      72.0  SSE
# 296     EAST 2023-04-14 00:00:00         60.0       53.0      78.0    S
#
#      wind speed  wind gust  pressure  precip.       condition    power  year  \
# 0           5.0        0.0     29.40      0.0            Fair  1380.66  2023
# 1          22.0       35.0     29.29      0.0  Cloudy / Windy  1297.34  2023
# 2           7.0        0.0     29.42      0.0            Fair  1230.50  2023
# 3          10.0        0.0     29.42      0.0            Fair  1137.21  2023
# 4           9.0        0.0     29.42      0.0            Fair  1126.79  2023
# ..          ...        ...       ...      ...             ...      ...   ...
# 292         7.0        0.0     29.19      0.0            Fair  1573.11  2023
# 293         7.0        0.0     29.20      0.0            Fair  1616.33  2023
# 294         7.0        0.0     29.22      0.0            Fair  1562.25  2023
# 295         7.0        0.0     29.22      0.0            Fair  1440.86  2023
# 296         7.0        0.0     29.22      0.0            Fair  1333.16  2023
#
#       date   hour  forecast_power  percent_error  forecast_savgol  \
# 0    04-01  00:00     1562.710240      13.185740      1441.687706
# 1    04-01  01:00     1378.352745       6.244527      1393.777923
# 2    04-01  02:00     1283.302055       4.291106      1361.969897
# 3    04-01  04:00     1159.556300       1.965011      1344.443370
# 4    04-01  05:00     1334.570720      18.440057      1339.378084
# ..     ...    ...             ...            ...              ...
# 292  04-13  20:00     1598.525530       1.615623      1630.577965
# 293  04-13  21:00     1651.715590       2.189255      1610.392090
# 294  04-13  22:00     1657.645220       6.106271      1585.262694
# 295  04-13  23:00     1524.400080       5.797932      1555.320765
# 296  04-14  00:00     1527.327340      14.564444      1520.697295
#
#      savgol_percent_error
# 0                4.420184
# 1                7.433512
# 2               10.684266
# 3               18.222964
# 4               18.866700
# ..                    ...
# 292              3.653143
# 293              0.367370
# 294              1.473048
# 295              7.943920
# 296             14.067126
#
# [297 rows x 19 columns]
# Mean Average Percent Error - base forecast:  15.665878408439472
# Mean Average Percent Error - savgol forecast:  15.652828416641677
# Forecast Generation Time: 125.06178522109985 seconds
# -------------------------------
#      location                time  temperature  dew point  humidity wind  \
# 0    FAR_WEST 2023-04-01 00:00:00         48.0       11.0      22.0   SW
# 1    FAR_WEST 2023-04-01 01:00:00         60.0       57.0      90.0    S
# 2    FAR_WEST 2023-04-01 02:00:00         47.0       12.0      24.0    W
# 3    FAR_WEST 2023-04-01 03:00:00         48.0       12.0      24.0  WSW
# 4    FAR_WEST 2023-04-01 04:00:00         44.0        9.0      24.0    W
# ..        ...                 ...          ...        ...       ...  ...
# 308  FAR_WEST 2023-04-13 20:00:00         77.0       45.0      32.0    S
# 309  FAR_WEST 2023-04-13 21:00:00         73.0       48.0      41.0    S
# 310  FAR_WEST 2023-04-13 22:00:00         72.0       50.0      46.0  SSE
# 311  FAR_WEST 2023-04-13 23:00:00         72.0       50.0      46.0    S
# 312  FAR_WEST 2023-04-14 00:00:00         70.0       49.0      47.0  SSE
#
#      wind speed  wind gust  pressure  precip.     condition    power  year  \
# 0           3.0        0.0     27.11      0.0          Fair  5004.27  2023
# 1          17.0        0.0     26.81      0.0          Fair  5062.32  2023
# 2           6.0        0.0     27.11      0.0          Fair  5056.83  2023
# 3           5.0        0.0     27.12      0.0          Fair  5047.38  2023
# 4           7.0        0.0     27.12      0.0          Fair  5074.55  2023
# ..          ...        ...       ...      ...           ...      ...   ...
# 308        22.0       29.0     26.68      0.0  Fair / Windy  5520.25  2023
# 309        17.0        0.0     26.70      0.0          Fair  5441.90  2023
# 310        21.0        0.0     26.71      0.0  Fair / Windy  5498.03  2023
# 311        29.0       40.0     26.72      0.0  Fair / Windy  5494.85  2023
# 312        24.0       30.0     26.73      0.0  Fair / Windy  5421.62  2023
#
#       date   hour  forecast_power  percent_error  forecast_savgol  \
# 0    04-01  00:00     4384.760415      12.379620      4432.707205
# 1    04-01  01:00     4521.506290      10.683120      4442.674938
# 2    04-01  02:00     4392.298820      13.141260      4446.141998
# 3    04-01  03:00     4446.135435      11.912013      4444.426608
# 4    04-01  04:00     4496.456090      11.392023      4438.846990
# ..     ...    ...             ...            ...              ...
# 308  04-13  20:00     4670.342845      15.396171      4654.414193
# 309  04-13  21:00     4540.403560      16.565840      4639.556666
# 310  04-13  22:00     4651.919580      15.389338      4617.962888
# 311  04-13  23:00     4568.932165      16.850648      4589.418037
# 312  04-14  00:00     4577.781950      15.564316      4553.707287
#
#      savgol_percent_error
# 0               11.421502
# 1               12.240338
# 2               12.076499
# 3               11.945869
# 4               12.527278
# ..                    ...
# 308             15.684721
# 309             14.743809
# 310             16.006954
# 311             16.477829
# 312             16.008365
#
# [313 rows x 19 columns]
# Mean Average Percent Error - base forecast:  8.357843096832104
# Mean Average Percent Error - savgol forecast:  6.9906296965475505
# Forecast Generation Time: 126.21300053596497 seconds
# -------------------------------
#     location                time  temperature  dew point  humidity wind  \
# 0      NORTH 2023-04-01 00:00:00         48.0        7.0      19.0    W
# 1      NORTH 2023-04-01 01:00:00         60.0       55.0      83.0  SSW
# 2      NORTH 2023-04-01 02:00:00         43.0        8.0      24.0  WSW
# 3      NORTH 2023-04-01 03:00:00         43.0        7.0      23.0    W
# 4      NORTH 2023-04-01 04:00:00         40.0        7.0      26.0    W
# ..       ...                 ...          ...        ...       ...  ...
# 307    NORTH 2023-04-13 20:00:00         78.0       38.0      24.0    S
# 308    NORTH 2023-04-13 21:00:00         74.0       39.0      28.0  SSE
# 309    NORTH 2023-04-13 22:00:00         71.0       39.0      31.0  SSE
# 310    NORTH 2023-04-13 23:00:00         67.0       41.0      39.0  SSE
# 311    NORTH 2023-04-14 00:00:00         67.0       43.0      42.0    S
#
#      wind speed  wind gust  pressure  precip.      condition    power  year  \
# 0           9.0        0.0     26.68      0.0           Fair   879.55  2023
# 1          23.0       35.0     26.37      0.0   Fair / Windy   846.68  2023
# 2           7.0        0.0     26.71      0.0  Partly Cloudy   825.18  2023
# 3           9.0        0.0     26.72      0.0  Partly Cloudy   815.22  2023
# 4           7.0        0.0     26.73      0.0  Mostly Cloudy   805.39  2023
# ..          ...        ...       ...      ...            ...      ...   ...
# 307        14.0        0.0     26.29      0.0  Mostly Cloudy  1147.59  2023
# 308        14.0        0.0     26.29      0.0  Mostly Cloudy  1139.31  2023
# 309        12.0        0.0     26.29      0.0           Fair  1108.55  2023
# 310        13.0        0.0     26.30      0.0  Mostly Cloudy  1048.80  2023
# 311        13.0        0.0     26.31      0.0           Fair   977.99  2023
#
#       date   hour  forecast_power  percent_error  forecast_savgol  \
# 0    04-01  00:00      910.493570       3.518114       905.497740
# 1    04-01  01:00      892.748325       5.441055       923.311929
# 2    04-01  02:00      977.717020      18.485303       939.750230
# 3    04-01  03:00      979.873895      20.197480       954.692588
# 4    04-01  04:00      923.615490      14.679285       968.018946
# ..     ...    ...             ...            ...              ...
# 307  04-13  20:00      999.115250      12.937961      1010.191440
# 308  04-13  21:00      985.260500      13.521298       998.749702
# 309  04-13  22:00     1000.421555       9.754043       979.091020
# 310  04-13  23:00      929.134045      11.409797       949.932968
# 311  04-14  00:00      927.416665       5.171151       909.993116
#
#      savgol_percent_error
# 0                2.950115
# 1                9.050873
# 2               13.884271
# 3               17.108583
# 4               20.192571
# ..                    ...
# 307             11.972792
# 308             12.337318
# 309             11.678226
# 310              9.426681
# 311              6.952718
#
# [312 rows x 19 columns]
# Mean Average Percent Error - base forecast:  13.584902128129832
# Mean Average Percent Error - savgol forecast:  13.04911318181381
# Forecast Generation Time: 126.97740316390991 seconds
# -------------------------------
#     location                time  temperature  dew point  humidity wind  \
# 0    NORTH_C 2023-04-01 00:00:00         71.0       19.0      14.0    W
# 1    NORTH_C 2023-04-01 01:00:00         72.0       64.0      78.0    S
# 2    NORTH_C 2023-04-01 02:00:00         65.0       24.0      21.0    W
# 3    NORTH_C 2023-04-01 03:00:00         69.0       17.0      14.0    W
# 4    NORTH_C 2023-04-01 04:00:00         67.0       19.0      16.0    W
# ..       ...                 ...          ...        ...       ...  ...
# 308  NORTH_C 2023-04-13 20:00:00         74.0       50.0      43.0  SSE
# 309  NORTH_C 2023-04-13 21:00:00         73.0       50.0      44.0  SSE
# 310  NORTH_C 2023-04-13 22:00:00         71.0       50.0      47.0  SSE
# 311  NORTH_C 2023-04-13 23:00:00         69.0       51.0      53.0  SSE
# 312  NORTH_C 2023-04-14 00:00:00         68.0       51.0      55.0  VAR
#
#      wind speed  wind gust  pressure  precip.      condition     power  year  \
# 0           9.0        0.0     29.46      0.0           Fair  10692.23  2023
# 1          12.0       29.0     29.30      0.0         Cloudy   9872.25  2023
# 2           5.0        0.0     29.47      0.0           Fair   9288.33  2023
# 3           9.0        0.0     29.47      0.0           Fair   8881.32  2023
# 4           9.0        0.0     29.47      0.0  Mostly Cloudy   8653.04  2023
# ..          ...        ...       ...      ...            ...       ...   ...
# 308        14.0       21.0     29.21      0.0           Fair  13951.71  2023
# 309         7.0        0.0     29.22      0.0           Fair  13866.63  2023
# 310         7.0        0.0     29.24      0.0           Fair  13493.28  2023
# 311         6.0        0.0     29.24      0.0           Fair  12502.50  2023
# 312         6.0        0.0     29.23      0.0           Fair  11300.39  2023
#
#       date   hour  forecast_power  percent_error  forecast_savgol  \
# 0    04-01  00:00    14414.844255      34.816070     13053.622882
# 1    04-01  01:00    11583.075455      17.329641     13190.505463
# 2    04-01  02:00    13118.113750      41.232210     13243.149653
# 3    04-01  03:00    13201.747720      48.646234     13225.278838
# 4    04-01  04:00    12526.274355      44.761545     13150.616408
# ..     ...    ...             ...            ...              ...
# 308  04-13  20:00    12476.206435      10.575790     12805.068878
# 309  04-13  21:00    11793.979260      14.947040     12744.741236
# 310  04-13  22:00    12898.414970       4.408602     12613.952710
# 311  04-13  23:00    14414.991430      15.296872     12400.213611
# 312  04-14  00:00    10932.165090       3.258515     12091.034247
#
#      savgol_percent_error
# 0               22.085130
# 1               33.611947
# 2               42.578371
# 3               48.911185
# 4               51.976836
# ..                    ...
# 308              8.218642
# 309              8.090565
# 310              6.516779
# 311              0.818127
# 312              6.996610
#
# [313 rows x 19 columns]
# Mean Average Percent Error - base forecast:  9.070895062764889
# Mean Average Percent Error - savgol forecast:  7.918048017242067
# Forecast Generation Time: 127.72499442100525 seconds
# -------------------------------
#      location                time  temperature  dew point  humidity wind  \
# 0    SOUTHERN 2023-04-01 00:00:00         76.0       72.0      87.0   SE
# 1    SOUTHERN 2023-04-01 01:00:00         74.0       70.0      87.0   SE
# 2    SOUTHERN 2023-04-01 02:00:00         75.0       73.0      94.0  ESE
# 3    SOUTHERN 2023-04-01 03:00:00         75.0       72.0      90.0  ESE
# 4    SOUTHERN 2023-04-01 04:00:00         74.0       72.0      93.0  ESE
# ..        ...                 ...          ...        ...       ...  ...
# 308  SOUTHERN 2023-04-13 20:00:00         76.0       62.0      62.0   SE
# 309  SOUTHERN 2023-04-13 21:00:00         73.0       62.0      68.0   SE
# 310  SOUTHERN 2023-04-13 22:00:00         72.0       64.0      76.0   SE
# 311  SOUTHERN 2023-04-13 23:00:00         70.0       64.0      81.0   SE
# 312  SOUTHERN 2023-04-14 00:00:00         69.0       65.0      87.0  ESE
#
#      wind speed  wind gust  pressure  precip. condition    power  year   date  \
# 0           7.0        0.0     29.85      0.0    Cloudy  3646.67  2023  04-01
# 1          17.0       28.0     29.78      0.0      Fair  3503.27  2023  04-01
# 2           8.0        0.0     29.86      0.0    Cloudy  3343.30  2023  04-01
# 3           9.0        0.0     29.85      0.0    Cloudy  3217.59  2023  04-01
# 4           9.0        0.0     29.84      0.0    Cloudy  3045.56  2023  04-01
# ..          ...        ...       ...      ...       ...      ...   ...    ...
# 308        14.0        0.0     29.63      0.0      Fair  4166.59  2023  04-13
# 309        12.0        0.0     29.65      0.0      Fair  4203.84  2023  04-13
# 310        10.0        0.0     29.67      0.0      Fair  4099.21  2023  04-13
# 311         9.0        0.0     29.68      0.0      Fair  3755.24  2023  04-13
# 312        12.0        0.0     29.66      0.0      Fair  3455.81  2023  04-14
#
#       hour  forecast_power  percent_error  forecast_savgol  \
# 0    00:00     3453.070600       5.308937      3551.859903
# 1    01:00     3450.077365       1.518371      3381.587195
# 2    02:00     3203.526760       4.180697      3251.534043
# 3    03:00     3224.510870       0.215095      3159.544080
# 4    04:00     3138.668260       3.057180      3103.460941
# ..     ...             ...            ...              ...
# 308  20:00     4037.354335       3.101713      4067.868414
# 309  21:00     3567.668160      15.133113      4009.736436
# 310  22:00     4068.016470       0.760964      3952.866722
# 311  23:00     3848.034505       2.471067      3901.672005
# 312  00:00     3966.280990      14.771385      3860.565018
#
#      savgol_percent_error
# 0                2.599909
# 1                3.473406
# 2                2.744772
# 3                1.804019
# 4                1.901159
# ..                    ...
# 308              2.369362
# 309              4.617292
# 310              3.570036
# 311              3.899405
# 312             11.712305
#
# [313 rows x 19 columns]
# Mean Average Percent Error - base forecast:  9.404517781266623
# Mean Average Percent Error - savgol forecast:  8.332312954235706
# Forecast Generation Time: 124.93049359321594 seconds
# -------------------------------
#     location                time  temperature  dew point  humidity  wind  \
# 0    SOUTH_C 2023-04-01 00:00:00         58.0       53.0      84.0  CALM
# 1    SOUTH_C 2023-04-01 01:00:00         72.0       68.0      87.0     S
# 2    SOUTH_C 2023-04-01 02:00:00         51.0       49.0      92.0   NNW
# 3    SOUTH_C 2023-04-01 03:00:00         53.0       50.0      89.0  CALM
# 4    SOUTH_C 2023-04-01 04:00:00         49.0       47.0      93.0  CALM
# ..       ...                 ...          ...        ...       ...   ...
# 308  SOUTH_C 2023-04-13 20:00:00         65.0       54.0      68.0     S
# 309  SOUTH_C 2023-04-13 21:00:00         63.0       54.0      72.0    SE
# 310  SOUTH_C 2023-04-13 22:00:00         61.0       54.0      78.0   SSE
# 311  SOUTH_C 2023-04-13 23:00:00         64.0       54.0      70.0     S
# 312  SOUTH_C 2023-04-14 00:00:00         62.0       53.0      72.0     S
#
#      wind speed  wind gust  pressure  precip.      condition    power  year  \
# 0           0.0        0.0     29.45      0.0           Fair  7180.02  2023
# 1          15.0       24.0     29.33      0.0         Cloudy  6483.96  2023
# 2           6.0        0.0     29.47      0.0           Fair  5971.29  2023
# 3           0.0        0.0     29.47      0.0           Fair  5646.55  2023
# 4           0.0        0.0     29.47      0.0           Fair  5450.52  2023
# ..          ...        ...       ...      ...            ...      ...   ...
# 308         6.0        0.0     29.17      0.0  Partly Cloudy  7966.76  2023
# 309         3.0        0.0     29.18      0.0           Fair  7920.25  2023
# 310         5.0        0.0     29.19      0.0           Fair  7643.01  2023
# 311        12.0        0.0     29.20      0.0           Fair  7131.02  2023
# 312         9.0        0.0     29.20      0.0           Fair  6528.09  2023
#
#       date   hour  forecast_power  percent_error  forecast_savgol  \
# 0    04-01  00:00     6313.798365      12.064335      6287.460830
# 1    04-01  01:00     6521.126325       0.573204      6166.460778
# 2    04-01  02:00     5834.809715       2.285608      6105.570798
# 3    04-01  03:00     5732.683460       1.525417      6097.484055
# 4    04-01  04:00     6040.425370      10.822919      6134.893712
# ..     ...    ...             ...            ...              ...
# 308  04-13  20:00     7547.614095       5.261184      7403.313148
# 309  04-13  21:00     7059.396050      10.869025      7233.479557
# 310  04-13  22:00     6775.298565      11.353007      7018.819624
# 311  04-13  23:00     7203.120050       1.011076      6758.278424
# 312  04-14  00:00     6319.615330       3.193502      6450.801035
#
#      savgol_percent_error
# 0               12.431152
# 1                4.896687
# 2                2.248774
# 3                7.986010
# 4               12.556118
# ..                    ...
# 308              7.072472
# 309              8.671070
# 310              8.166814
# 311              5.227044
# 312              1.183945
#
# [313 rows x 19 columns]
# Mean Average Percent Error - base forecast:  13.057986521838554
# Mean Average Percent Error - savgol forecast:  13.057456132880297
# Forecast Generation Time: 124.72337794303894 seconds
# -------------------------------
#     location                time  temperature  dew point  humidity  wind  \
# 0       WEST 2023-04-01 00:00:00         53.0       19.0      26.0   SSW
# 1       WEST 2023-04-01 01:00:00         70.0       61.0      73.0     S
# 2       WEST 2023-04-01 02:00:00         54.0       19.0      25.0    SW
# 3       WEST 2023-04-01 03:00:00         53.0       18.0      25.0   SSW
# 4       WEST 2023-04-01 04:00:00         53.0       17.0      24.0  CALM
# ..       ...                 ...          ...        ...       ...   ...
# 309     WEST 2023-04-13 20:00:00         77.0       43.0      30.0   SSE
# 310     WEST 2023-04-13 21:00:00         73.0       45.0      37.0    SE
# 311     WEST 2023-04-13 22:00:00         73.0       44.0      35.0   SSE
# 312     WEST 2023-04-13 23:00:00         72.0       46.0      40.0   SSE
# 313     WEST 2023-04-14 00:00:00         70.0       47.0      44.0   SSE
#
#      wind speed  wind gust  pressure  precip.              condition    power  \
# 0           9.0        0.0     28.18      0.0                   Fair  1050.53
# 1          21.0       32.0     27.89      0.0  Partly Cloudy / Windy  1016.67
# 2           6.0        0.0     28.20      0.0                   Fair   987.16
# 3           6.0        0.0     28.19      0.0                   Fair   977.15
# 4           0.0        0.0     28.20      0.0                   Fair   972.61
# ..          ...        ...       ...      ...                    ...      ...
# 309        14.0        0.0     27.81      0.0                   Fair  1272.70
# 310        14.0        0.0     27.82      0.0                   Fair  1277.82
# 311        16.0        0.0     27.83      0.0                   Fair  1263.28
# 312        21.0       29.0     27.84      0.0           Fair / Windy  1201.05
# 313        20.0       28.0     27.83      0.0                   Fair  1124.02
#
#      year   date   hour  forecast_power  percent_error  forecast_savgol  \
# 0    2023  04-01  00:00      966.858550       7.964689       966.934881
# 1    2023  04-01  01:00      966.858550       4.899471       967.136933
# 2    2023  04-01  02:00      966.858550       2.056551       967.267893
# 3    2023  04-01  03:00      968.308838       0.904791       967.337115
# 4    2023  04-01  04:00      968.308838       0.442229       967.353953
# ..    ...    ...    ...             ...            ...              ...
# 309  2023  04-13  20:00      966.858550      24.030915       966.858550
# 310  2023  04-13  21:00      966.858550      24.335309       966.858550
# 311  2023  04-13  22:00      966.858550      23.464430       966.858550
# 312  2023  04-13  23:00      966.858550      19.498893       966.858550
# 313  2023  04-14  00:00      966.858550      13.982087       966.858550
#
#      savgol_percent_error
# 0                7.957423
# 1                4.872089
# 2                2.015084
# 3                1.004235
# 4                0.540406
# ..                    ...
# 309             24.030915
# 310             24.335309
# 311             23.464430
# 312             19.498893
# 313             13.982087
#
# [314 rows x 19 columns]

# %%
##Automated daily forecasting script from current weather forecast


import pandas as pd
import numpy as np
from scipy.signal import savgol_filter
import pymilvus
import time as time
import math
import matplotlib.pyplot as plt
import statsmodels.api as sm
from pathlib import Path
from pymilvus import (
    connections,
    utility,
    FieldSchema, CollectionSchema, DataType,
    Collection,
)

from sqlalchemy import create_engine, MetaData, delete, Table, Column
import sqlalchemy
from sqlalchemy.engine import URL
import pypyodbc


start_time = time.time()

plt.rcParams['figure.figsize'] = [12, 5] #plot size 10"w x 5"h

# set up embedding model
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

#initialize df for access outside of loop
df = pd.DataFrame()

####################################

#open docker and run milvus
#wait 1min?

####################################
# connect to milvus vdb
connections.connect(
  alias="default",
  user='root',
  password='tecafs',
  host='localhost',
  port='19530'
)

###################################
# connect to SQL
# declares the variables and defines them for the server connections, along with the table names that are going to be assigned
SERVER_NAME = 'tcp:tecafs.database.windows.net,1433'
DATABASE_NAME = 'TecafsSqlDatabase'
TABLE_NAME = 'hist_data'

# makes the connection to the database with the connection string; has the driver, server name, database name, id, and password
connection_string = f"""
  DRIVER={{ODBC Driver 18 for SQL Server}};
  SERVER={SERVER_NAME};
  DATABASE={DATABASE_NAME};
  Uid={'tecafs2023'};
  Pwd={'Capstone50'};
"""

connection_url = URL.create('mssql+pyodbc', query={'odbc_connect': connection_string})
engine = create_engine(connection_url, module=pypyodbc)  

###################################

metadata = MetaData()
metadata.reflect(bind=engine)

VDB_daily_forecast = metadata.tables['VDB_daily_forecast']

conn = engine.connect()

clear_table = VDB_daily_forecast.delete()
conn.execute(clear_table)
conn.commit()

###################################


locationslist = ['COAST', 'EAST', 'FAR_WEST', 'NORTH', 'NORTH_C', 'SOUTHERN', 'SOUTH_C', 'WEST']

for i in range(8):
    location = locationslist[i]

    location_start_time = time.time()

    # Define the SQL query for current location
    sql_query = """
    SELECT *
    FROM weather_forecast
    WHERE Location = ?
    """
    
    # Execute the query with user input as parameters
    df = pd.read_sql_query(sql_query, engine, params = (location))

    ##################################
    
    #fix df formatting
    #df = df.drop(columns=['dew point', 'wind', 'wind gust', 'pressure', 'precip.'])
    #df = df.rename(columns={"wind speed": "wind_speed"})
    df['year'] = df['time'].dt.year.astype(int)
    df['date'] = df['time'].dt.strftime('%m-%d')
    df['hour'] = df['time'].dt.strftime('%H:%M')


    #need to trim wind to just wind speed
    

    df = df.sort_values(by=['location', 'time']) #sorts by datetime within each location
    df = df.reset_index(drop=True)
    
    #reorder columns to match vdb
    #df = df[['vector', 'location', 'time', 'year', 'date', 'hour', 'temperature', 'humidity', 'wind speed', 'condition', 'power']]
        
    ###################################

    #define embedding function
    def get_embedding(prevec):
        text = prevec
        embedding = model.encode(text, show_progress_bar = False)
        return embedding
    
    # Create the prevec conglomeration by combining values from other columns and embed it into 'vector' column 
    df['vector'] = df.apply(lambda row: get_embedding(f"{row['year']}/{row['date']}/{row['hour']}/{row['hour']}/{row['hour']}/{row['temperature']}/{row['temperature']}/{row['humidity']}/{row['wind speed']}/{row['condition']}"), axis=1)

    ##################################
    
    collection = Collection("historical_data_21_22")  #get existing milvus collection
    collection.load()  #load collection
    
    def search(text, hour, date, year, location, top_k = 10):
        # AUTOINDEX does not require any search params, chosen to specify metric
        search_params = {
          "metric_type": "L2",
          
        }
        
        #do similarity search
        results = collection.search(
          data = [text],
          anns_field='vector',
          param=search_params,
          limit = top_k,  # Limit to top_k results per search
          expr='location=="{0}"'.format(location),
          output_fields=['index', 'location', 'year', 'date', 'hour', 'temperature', 'humidity', 'wind_speed', 'condition', 'power']
        )
        avg_power = 0
        
        #sum the top_k power values
        for hit in  results[0]:
            #print (hit.entity.get(['location', 'year', 'date', 'hour', 'temperature', 'humidity', 'wind_speed', 'condition', 'power']))
            avg_power += (hit.entity.get('power')*(1.015**(year-hit.entity.get('year')))) #normalize to current year equivalent - 1.5% increase per year
            
        
        #calculate average power, adjust to tune for best results
        month = int(date.split('-')[0])
        hr = int(hour.split(':')[0])
        
        yearly_amp = (-1000*math.sin((math.pi/6)*(month-1)+1))+(300*math.sin((math.pi/3)*(month-1)+1))+1700
        
        #avg_power= (-(yearly_amp)*math.sin((math.pi/12)*hr))+(avg_power/top_k)
        #avg_power= (-500*math.sin((math.pi/12)*hr))+(avg_power/top_k)
        avg_power= (avg_power/top_k)
        return avg_power

        #normalization percentage variable throughout year on bell curve - 0-5%
        #amplitude boost variable throughout year on bell curve (start above 0 boost, increase to max boost in august), also as a function of current value

    ##################################

    df['forecast_power'] = df.apply(lambda row: search(row['vector'], row['hour'], row['date'], row['year'], row['location']), axis=1)  
    
    ##################################
    
    #apply savitsky-golay filter for smoothing
    df['forecast_savgol'] = df[['forecast_power']].apply(lambda x: savgol_filter(x,18,3))
    
    ##################################
    
    location_end_time = time.time()
    location_elapsed_time = location_end_time - location_start_time
    
    # Write the modified DataFrame back to a new CSV file
    data_folder = Path("/mnt/c/Users/wcans/milvus_compose/ERCOT_Hourly_Load_2022/")
    output_csv_file_path = data_folder / 'dailyforecast_out.csv'  # Replace with the desired output path
    #not enabled at the moment
    #df.to_csv(output_csv_file_path, index=False)

    '''
    #print data
    #create and print plots
    df.plot(x="date", y=["forecast_power", "power", "forecast_savgol"], kind="line")
    # Display the plot
    plt.title('Forecast Power vs Actual Power Over Time')
    plt.xlabel('Date')
    plt.ylabel('Power (megawatt-hours)')
    plt.legend(['Forecast Power', 'Power', 'SavGol Forecast'])
    plt.savefig('power_figure.png')
    plt.show(block=True)
    
    
    df.plot(x='date', y=['percent_error', 'savgol_percent_error'], kind='line')
    # Display the plot
    plt.title('Percent Error')
    plt.xlabel('Date')
    plt.ylabel('Percentage')
    plt.legend(['Forecast Error', 'SavGol Error'])
    plt.savefig('error_figure.png')
    plt.show(block=True)
    
    print('Mean Average Percent Error - base forecast: ', mean_percent_error)
    print('Mean Average Percent Error - savgol forecast: ', savgol_mean_percent_error)'''
    print(f"Forecast Generation Time: {location_elapsed_time} seconds")
    print('-------------------------------')

    '''
    #check for missing hours in the forecast
    expected_diff = pd.Timedelta(hours=1)
    rollover_diff = pd.Timedelta(hours=23)
    
    #convert time to datetime
    df['time'] = pd.to_datetime(df['time'], format='%H:%M')
    
    # Calculate the actual difference between each consecutive datetime
    time_diff = df['time'].diff()
    
    # Find the rows where the difference is not as expected
    missing_hours = df[(time_diff != expected_diff) & (time_diff != rollover_diff)]
    missing_hours['time'] = missing_hours['time'].dt.strftime('%H:%M')
    
    # Print a notification if there are missing hours
    if not missing_hours.empty:
      print("Notification: Missing hour(s) detected between the following timestamps:")
      print(missing_hours[['date', 'time']])
    else:
      print("No missing hours detected.")
    
    #convert time back to strings
    df['time'] = df['time'].dt.strftime('%H:%M')
    '''
    df = df.drop(columns=['vector']) #'time_diff', 'missing_hours'
    
    #print(df)
    
    #Format forecast for insertion
    df = df.drop(columns=['forecast_power'])
    
    new_column_name = 'forecast power'
    df.rename(columns={'forecast_savgol': new_column_name}, inplace=True)
    
    #Add to SQL
    df.to_sql('VDB_daily_forecast', con=engine, if_exists='append', index=False)


end_time = time.time()
elapsed_time = end_time - start_time
print("Added all forecasts to SQL")
print(f"Total Generation Time: {elapsed_time} seconds")
